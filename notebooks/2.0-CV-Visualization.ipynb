# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import seaborn as sns; sns.set()

# %%
Data_candy_raw = pd.read_csv('../data/processed/candy_vis.csv')

# %%
sns.pairplot(Data_candy_raw, hue = 'group')
